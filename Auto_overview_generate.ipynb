# %%
# 在Jupyter Cell中这样使用
from nanodata_overview_jupyter import JupyterNanoDataOverviewGenerator

## 注意更改文件路径
generator = JupyterNanoDataOverviewGenerator()
generator.generate_overview("YOUR/PATH/TO/DATA/FILES", ".sxm", cols_per_row=  5, max_per_fig=  20)
